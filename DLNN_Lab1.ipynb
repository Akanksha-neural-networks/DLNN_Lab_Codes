# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha-neural-networks/DLNN_Lab_Codes/blob/main/DLNN_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
print(keras.__version__)
# Out:
# 2.15.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers,models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/diabetes.csv')
x=df.iloc[:,0:8]
y=df["Outcome"]
obj=StandardScaler()
x_=obj.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_,y,test_size=0.2,random_state=0)

# %%
model = models.Sequential()
model.add(layers.Dense(100,activation="relu"))
model.add(layers.Dense(50,activation="relu"))
model.add(layers.Dense(12,activation="relu"))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = model.fit(x_train,y_train,epochs=50,validation_data=(x_test,y_test))
results = model.evaluate(x_test,y_test)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 5s 62ms/step - loss: 0.6479 - accuracy: 0.6498 - val_loss: 0.5738 - val_accuracy: 0.6948
# Epoch 2/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5656 - accuracy: 0.6922 - val_loss: 0.5057 - val_accuracy: 0.7468
# Epoch 3/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5231 - accuracy: 0.7524 - val_loss: 0.4693 - val_accuracy: 0.7987
# Epoch 4/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4990 - accuracy: 0.7720 - val_loss: 0.4638 - val_accuracy: 0.8052
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4840 - accuracy: 0.7932 - val_loss: 0.4573 - val_accuracy: 0.7792
# Epoch 6/50
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4759 - accuracy: 0.7932 - val_loss: 0.4524 - val_accuracy: 0.7857
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='val_accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
